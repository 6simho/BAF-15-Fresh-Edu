# %% [markdown]
# ## 관심 있는 주제

# %% [markdown]
# 자기 개발에 관한 주제- 모발 건강 예측 데이터, 피부 케어 데이터 등

# %% [markdown]
# ## 이유

# %% [markdown]
# 사람들은 본인을 가꾸는 일에 굉장히 많은 힘을 쓰며 살아가고 있습니다. 그 중 중요하게 여겨지는 주제로 모발 건강이 있는데, 모발 건강에는 어떠한 요소들이 영향이 미칠지, 일상 속에서 탈모를 예방할 수 있는 방법에는 어떠한 것들이 있는지 궁금해져서 선택하게 되었습니다.

# %% [markdown]
# # 따릉이 데이터 EDA

# %%
import pandas as pd

# %%
# %pwd #현재 폴더 위치 확인
# Out:
# 'C:\\Users\\6aimh\\OneDrive\\바탕 화면\\b.a.f'

# %% [markdown]
# #### 상대경로로 파일 불러오기

# %%
cycle=pd.read_csv("./train.csv",encoding='cp949')
cycle
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0     24/10/2018               1492    16              NaN           42
# 1     01/05/2018               1536    14             23.0           64
# 2     14/11/2018                327     2              6.2           59
# 3     31/08/2018                170     4             23.2           83
# 4     26/06/2018                 45     5             23.7           64
# ...          ...                ...   ...              ...          ...
# 7003  08/02/2018                255     7             -9.6           67
# 7004  28/03/2018                104     4             10.6           77
# 7005  30/04/2018                569     0             14.7           54
# 7006  29/05/2018               2234     8             20.5           66
# 7007  20/09/2018               1290    17             19.3           76
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0                  1.3              1976                        5.0
# 1                  2.8               520                       15.8
# 2                  0.6              1584                       -1.2
# 3                  1.6              1102                       20.1
# 4                  0.9               876                       16.4
# ...                ...               ...                        ...
# 7003               1.0              1503                      -14.5
# 7004               0.9               422                        6.7
# 7005               1.3               718                        5.4
# 7006               1.7              1062                       13.9
# 7007               2.1              2000                       14.9
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 0                        1.22           0.0            0.0     NaN
# 1                        1.59           0.0            0.0  Spring
# 2                        0.00           0.0            0.0  Autumn
# 3                        0.00           0.0            0.0  Summer
# 4                        0.00           0.1            0.0  Summer
# ...                       ...           ...            ...     ...
# 7003                     0.00           0.0            0.0  Winter
# 7004                     0.00           0.0            0.0  Spring
# 7005                     0.00           0.0            0.0  Spring
# 7006                     0.34           0.0            0.0  Spring
# 7007                     0.21           0.0            0.0     NaN
#
#          Holiday Functioning Day
# 0     No Holiday             Yes
# 1        Holiday             Yes
# 2     No Holiday             Yes
# 3     No Holiday             Yes
# 4     No Holiday             Yes
# ...          ...             ...
# 7003  No Holiday             Yes
# 7004  No Holiday             Yes
# 7005  No Holiday             Yes
# 7006  No Holiday             Yes
# 7007  No Holiday             Yes
#
# [7008 rows x 14 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'  #선명하게 만들기
# %matplotlib inline

# %% [markdown]
# # 가설 세우기

# %% [markdown]
# - 기온이 높으면 자전거 대여 수가 적을 것이다.
# - 습도가 높으면 자전거 대여 수가 적을 것이다.
# - 바람 세기가 세면 자전거 대여 수가 적을 것이다.
# - 태양 복사열이 세면 자전거 대여 수가 적을 것이다.
# - 강우량이 많으면 자전거 대여 수가 적을 것이다.
# - 적설량이 많으면 자전거 대여 수가 적을 것이다.
# - 겨울이 가장 자전거 대여 수가 적을 것이다.
# - 휴일이 평일에 비해 자전거 대여 수가 많을 것이다.
# - 기능 가능일에만 자전거를 대여할 수 있을 것이다.
# - 기온, 강우량, 강설량이 자전거 대여 수에 큰 영향을 미칠 것이다.
# - 휴일여부와 계절에 따라서 나뉘는 자전거 대여 수는 멱확하게 보일 것이다.
# - 평일에는 출퇴근길 직장인들의 사용량이 많을 것이다. 따라서 사용 시간은 짧을 것이다.
# - 휴일에는 나들이 나온 사람들의 사용량이 많을 것이다. 따라서 사용 시간은 길 것이다.
# - 학생들 여름방학 기간인 7, 8월에는 자전거 사용량이 많을 것이다.

# %% [markdown]
# # 피처 설명
# - Date                           : 날짜
# - Rented Bike Count              : 대여한 자전거 수
# - Hour                           : 대여 시간
# - Temperature(°C)               : 기온(°C)
# - Humidity(%)                    : 습도(%)
# - Wind speed (m/s)               : 바람 세기(m/s)
# - Visibility (10m)               : 시야(10m)
# - Dew point temperature(°C)     : 노점온도(일정한 압력에서 공기의 온도를 낮추어 갈 때 공기 중의 수증기가 포화하여 이슬이 맺힐 때의 온도,습도에 비례)
# - Solar Radiation (MJ/m2)        : 태양 복사열(MJ/m2)
# - Rainfall(mm)                   : 강우량(mm)
# - Snowfall (cm)                  : 적설량(cm)
# - Seasons                        : 계절
# - Holiday                        : 휴일
# - Functioning Day                : 기능 가능일

# %% [markdown]
# # 1. 데이터 살펴보기
# >정보 확인

# %%
cycle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7008 entries, 0 to 7007
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       7008 non-null   object
#  1   Rented Bike Count          7008 non-null   int64
#  2   Hour                       7008 non-null   int64
#  3   Temperature(°C)            6306 non-null   float64
#  4   Humidity(%)                7008 non-null   int64
#  5   Wind speed (m/s)           6303 non-null   float64
#  6   Visibility (10m)           7008 non-null   int64
#  7   Dew point temperature(°C)  7008 non-null   float64
#  8   Solar Radiation (MJ/m2)    7008 non-null   float64
#  9   Rainfall(mm)               7008 non-null   float64
#  10  Snowfall (cm)              7008 non-null   float64
#  11  Seasons                    6309 non-null   object
#  12  Holiday                    7008 non-null   object
#  13  Functioning Day            7008 non-null   object
# dtypes: float64(6), int64(4), object(4)
# memory usage: 766.6+ KB

# %% [markdown]
# > 기술통계량 확인

# %%
cycle.describe()
# Out:
#        Rented Bike Count         Hour  Temperature(°C)  Humidity(%)  \
# count        7008.000000  7008.000000      6306.000000  7008.000000
# mean          708.597603    11.559646        13.030082    58.141981
# std           647.980391     6.923619        11.986773    20.423404
# min             0.000000     0.000000       -17.800000     0.000000
# 25%           191.000000     6.000000         3.600000    42.000000
# 50%           505.500000    12.000000        14.000000    57.000000
# 75%          1071.000000    18.000000        22.675000    74.000000
# max          3556.000000    23.000000        39.400000    98.000000
#
#        Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# count       6303.000000       7008.000000                7008.000000
# mean           1.732937       1440.761558                   4.042066
# std            1.030763        607.545441                  13.121249
# min            0.000000         27.000000                 -30.600000
# 25%            1.000000        946.000000                  -4.800000
# 50%            1.500000       1703.000000                   5.100000
# 75%            2.350000       2000.000000                  14.900000
# max            7.400000       2000.000000                  27.200000
#
#        Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)
# count              7008.000000   7008.000000    7008.000000
# mean                  0.574576      0.150271       0.075300
# std                   0.874529      1.134598       0.440936
# min                   0.000000      0.000000       0.000000
# 25%                   0.000000      0.000000       0.000000
# 50%                   0.010000      0.000000       0.000000
# 75%                   0.930000      0.000000       0.000000
# max                   3.520000     35.000000       8.800000

# %% [markdown]
# > 결측치 확인하기

# %%
cycle.isna().sum().sort_values()
# Out:
# Date                           0
# Rented Bike Count              0
# Hour                           0
# Humidity(%)                    0
# Visibility (10m)               0
# Dew point temperature(°C)      0
# Solar Radiation (MJ/m2)        0
# Rainfall(mm)                   0
# Snowfall (cm)                  0
# Holiday                        0
# Functioning Day                0
# Seasons                      699
# Temperature(°C)              702
# Wind speed (m/s)             705
# dtype: int64

# %% [markdown]
# 각 피처당 전체 데이터에 대한 결측값의 비율이 어느정도인지 알아보려고 한다.

# %%
na=cycle.isna().sum().values
total=cycle.count().values
index1=cycle.columns
data1={'na':na,'total': total}
na_1=pd.DataFrame(data=data1,index=index1)
na_1
na_1['na_percent']=round(na_1['na']/na_1['total']*100,2)
na_1
# Out:
#                             na  total  na_percent
# Date                         0   7008        0.00
# Rented Bike Count            0   7008        0.00
# Hour                         0   7008        0.00
# Temperature(°C)            702   6306       11.13
# Humidity(%)                  0   7008        0.00
# Wind speed (m/s)           705   6303       11.19
# Visibility (10m)             0   7008        0.00
# Dew point temperature(°C)    0   7008        0.00
# Solar Radiation (MJ/m2)      0   7008        0.00
# Rainfall(mm)                 0   7008        0.00
# Snowfall (cm)                0   7008        0.00
# Seasons                    699   6309       11.08
# Holiday                      0   7008        0.00
# Functioning Day              0   7008        0.00

# %% [markdown]
# -> 결측값이 대부분인 피처라면 데이터 분석 과정에서 불필요하다고 느껴서 없애려고 했지만 결측값이 있는 Temperature(°C), Wind speed (m/s), Seasons 피처에서 결측값의 비율이 11% 정도로, 대부분을 차지하지 않는다고 판단했기에 이 피처들도 가져가려고 한다.

# %% [markdown]
# #### Temperature(°C), Wind speed (m/s), Seasons 피처를 na값에 집중해서 살펴보자

# %%
cycle[cycle['Temperature(°C)'].isna()]
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0     24/10/2018               1492    16              NaN           42
# 6     04/07/2018                941    11              NaN           60
# 11    24/05/2018               1390     7              NaN           61
# 18    10/04/2018                133    21              NaN           70
# 19    10/11/2018                754     0              NaN           77
# ...          ...                ...   ...              ...          ...
# 6978  27/02/2018                 72     5              NaN           50
# 6979  23/02/2018                 42     0              NaN           86
# 6983  28/11/2018               1540     8              NaN           29
# 6999  15/11/2018               1416    17              NaN           38
# 7002  18/01/2018                261    11              NaN           75
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0                  1.3              1976                        5.0
# 6                  2.3              1861                       21.3
# 11                 1.3              1818                        5.1
# 18                 7.3              1634                       11.9
# 19                 0.9               433                        7.4
# ...                ...               ...                        ...
# 6978               0.1              1026                       -8.6
# 6979               2.7                54                       -0.3
# 6983               1.1              1337                      -14.1
# 6999               1.4               884                       -0.3
# 7002               1.8               301                       -2.1
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 0                        1.22           0.0            0.0     NaN
# 6                        2.61           0.0            0.0  Summer
# 11                       0.42           0.0            0.0  Spring
# 18                       0.00           0.5            0.0  Spring
# 19                       0.00           0.0            0.0  Autumn
# ...                       ...           ...            ...     ...
# 6978                     0.00           0.0            0.0  Winter
# 6979                     0.00           0.4            0.4  Winter
# 6983                     0.02           0.0            0.0     NaN
# 6999                     0.29           0.0            0.0  Autumn
# 7002                     0.35           0.0            0.0  Winter
#
#          Holiday Functioning Day
# 0     No Holiday             Yes
# 6     No Holiday             Yes
# 11    No Holiday             Yes
# 18    No Holiday             Yes
# 19    No Holiday             Yes
# ...          ...             ...
# 6978  No Holiday             Yes
# 6979  No Holiday             Yes
# 6983  No Holiday             Yes
# 6999  No Holiday             Yes
# 7002  No Holiday             Yes
#
# [702 rows x 14 columns]

# %%
sns.barplot(x=cycle['Temperature(°C)']>=33,y=cycle['Rented Bike Count'])
# Out:
# <AxesSubplot:xlabel='Temperature(°C)', ylabel='Rented Bike Count'>

# %%
sns.barplot(x=cycle['Temperature(°C)']>=33,y=cycle['Hour'])
# Out:
# <AxesSubplot:xlabel='Temperature(°C)', ylabel='Hour'>

# %% [markdown]
# #### Temperature(°C) 피처의 결측값은 이 피처의 평균값으로 대체하겠다.

# %%
cycle['Temperature(°C)'].fillna(cycle['Temperature(°C)'].mean(),inplace=True)
cycle
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0     24/10/2018               1492    16        13.030082           42
# 1     01/05/2018               1536    14        23.000000           64
# 2     14/11/2018                327     2         6.200000           59
# 3     31/08/2018                170     4        23.200000           83
# 4     26/06/2018                 45     5        23.700000           64
# ...          ...                ...   ...              ...          ...
# 7003  08/02/2018                255     7        -9.600000           67
# 7004  28/03/2018                104     4        10.600000           77
# 7005  30/04/2018                569     0        14.700000           54
# 7006  29/05/2018               2234     8        20.500000           66
# 7007  20/09/2018               1290    17        19.300000           76
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0                  1.3              1976                        5.0
# 1                  2.8               520                       15.8
# 2                  0.6              1584                       -1.2
# 3                  1.6              1102                       20.1
# 4                  0.9               876                       16.4
# ...                ...               ...                        ...
# 7003               1.0              1503                      -14.5
# 7004               0.9               422                        6.7
# 7005               1.3               718                        5.4
# 7006               1.7              1062                       13.9
# 7007               2.1              2000                       14.9
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 0                        1.22           0.0            0.0     NaN
# 1                        1.59           0.0            0.0  Spring
# 2                        0.00           0.0            0.0  Autumn
# 3                        0.00           0.0            0.0  Summer
# 4                        0.00           0.1            0.0  Summer
# ...                       ...           ...            ...     ...
# 7003                     0.00           0.0            0.0  Winter
# 7004                     0.00           0.0            0.0  Spring
# 7005                     0.00           0.0            0.0  Spring
# 7006                     0.34           0.0            0.0  Spring
# 7007                     0.21           0.0            0.0     NaN
#
#          Holiday Functioning Day
# 0     No Holiday             Yes
# 1        Holiday             Yes
# 2     No Holiday             Yes
# 3     No Holiday             Yes
# 4     No Holiday             Yes
# ...          ...             ...
# 7003  No Holiday             Yes
# 7004  No Holiday             Yes
# 7005  No Holiday             Yes
# 7006  No Holiday             Yes
# 7007  No Holiday             Yes
#
# [7008 rows x 14 columns]

# %%
cycle[cycle['Wind speed (m/s)'].isna()]
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 10    21/03/2018                374    10         3.600000           37
# 23    14/03/2018                309     1        13.700000           73
# 33    26/06/2018                 26    14        21.000000           97
# 51    09/01/2018                320     9        -6.000000           61
# 52    16/07/2018                688    11        31.500000           51
# ...          ...                ...   ...              ...          ...
# 6948  11/10/2018               1398    21        13.030082           52
# 6953  08/03/2018                 17     5         3.100000           90
# 6975  22/09/2018               1062    11        22.700000           55
# 6993  06/05/2018                211    13        16.400000           94
# 6998  29/07/2018                644    12        33.800000           47
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 10                 NaN              2000                       -9.7
# 23                 NaN              1182                        8.9
# 33                 NaN               381                       20.4
# 51                 NaN              1547                      -12.3
# 52                 NaN              1498                       20.1
# ...                ...               ...                        ...
# 6948               NaN              2000                        0.0
# 6953               NaN               974                        1.6
# 6975               NaN              1297                       13.1
# 6993               NaN              1947                       15.4
# 6998               NaN              1962                       20.9
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 10                       0.83           0.0            0.0  Spring
# 23                       0.00           0.0            0.0  Spring
# 33                       0.26           2.5            0.0  Summer
# 51                       0.13           0.0            0.6  Winter
# 52                       2.83           0.0            0.0  Summer
# ...                       ...           ...            ...     ...
# 6948                     0.00           0.0            0.0  Autumn
# 6953                     0.00           0.0            0.0  Spring
# 6975                     1.86           0.0            0.0  Autumn
# 6993                     0.78           0.0            0.0  Spring
# 6998                     1.92           0.0            0.0  Summer
#
#          Holiday Functioning Day
# 10    No Holiday             Yes
# 23    No Holiday             Yes
# 33    No Holiday             Yes
# 51    No Holiday             Yes
# 52    No Holiday             Yes
# ...          ...             ...
# 6948  No Holiday             Yes
# 6953  No Holiday             Yes
# 6975  No Holiday             Yes
# 6993  No Holiday             Yes
# 6998  No Holiday             Yes
#
# [705 rows x 14 columns]

# %%
cycle[cycle['Seasons'].isna()]
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0     24/10/2018               1492    16        13.030082           42
# 22    31/08/2018                987    14        29.300000           41
# 30    09/11/2018                  0    23        10.900000           76
# 47    15/09/2018               1566    18        13.030082           76
# 55    24/01/2018                121    22       -15.200000           45
# ...          ...                ...   ...              ...          ...
# 6926  15/03/2018                567    21        10.400000           96
# 6968  22/07/2018                772     1        13.030082           60
# 6983  28/11/2018               1540     8        13.030082           29
# 6988  13/06/2018               2088    14        26.600000           50
# 7007  20/09/2018               1290    17        19.300000           76
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0                  1.3              1976                        5.0
# 22                 1.9              1928                       14.6
# 30                 1.2               456                        6.8
# 47                 1.2              2000                       19.6
# 55                 4.0              2000                      -24.4
# ...                ...               ...                        ...
# 6926               2.7               499                        9.7
# 6968               0.8              2000                       18.8
# 6983               1.1              1337                      -14.1
# 6988               2.4              1119                       15.3
# 7007               2.1              2000                       14.9
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 0                        1.22           0.0            0.0     NaN
# 22                       3.00           0.0            0.0     NaN
# 30                       0.00           0.0            0.0     NaN
# 47                       0.12           0.0            0.0     NaN
# 55                       0.00           0.0            0.7     NaN
# ...                       ...           ...            ...     ...
# 6926                     0.00           0.0            0.0     NaN
# 6968                     0.00           0.0            0.0     NaN
# 6983                     0.02           0.0            0.0     NaN
# 6988                     2.95           0.0            0.0     NaN
# 7007                     0.21           0.0            0.0     NaN
#
#          Holiday Functioning Day
# 0     No Holiday             Yes
# 22    No Holiday             Yes
# 30    No Holiday              No
# 47    No Holiday             Yes
# 55    No Holiday             Yes
# ...          ...             ...
# 6926  No Holiday             Yes
# 6968  No Holiday             Yes
# 6983  No Holiday             Yes
# 6988  No Holiday             Yes
# 7007  No Holiday             Yes
#
# [699 rows x 14 columns]

# %% [markdown]
# #### 중복값 확인하기

# %%
cycle[cycle.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Rented Bike Count, Hour, Temperature(°C), Humidity(%), Wind speed (m/s), Visibility (10m), Dew point temperature(°C), Solar Radiation (MJ/m2), Rainfall(mm), Snowfall (cm), Seasons, Holiday, Functioning Day]
# Index: []

# %% [markdown]
# #### 날짜 오름차순에 따라 데이터 정리

# %%
cycle['Date']=pd.to_datetime(cycle['Date'],dayfirst=True)
cycle=cycle.sort_values(by='Date')
cycle
# Out:
#            Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 2198 2017-12-01                181     6        13.030082           35
# 2442 2017-12-01                107     3        -6.200000           40
# 5689 2017-12-01                447    14         3.000000           26
# 613  2017-12-01                173     2        -6.000000           39
# 1659 2017-12-01                398    22        13.030082           83
# ...         ...                ...   ...              ...          ...
# 6820 2018-11-30                720    12         6.600000           35
# 4091 2018-11-30                116     4        13.030082           71
# 1627 2018-11-30                456     1         1.300000           63
# 54   2018-11-30                740    13         7.100000           24
# 121  2018-11-30               1047    17         6.000000           29
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 2198               1.3              2000                      -19.5
# 2442               0.9              2000                      -17.6
# 5689               2.0              2000                      -14.6
# 613                1.0              2000                      -17.7
# 1659               1.5              1380                       -3.4
# ...                ...               ...                        ...
# 6820               1.3              1409                       -7.8
# 4091               0.4              1345                       -5.1
# 1627               2.0              1379                       -4.9
# 54                 2.8              1838                      -12.1
# 121                2.1              1877                      -10.7
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 2198                     0.00           0.0            0.0  Winter
# 2442                     0.00           0.0            0.0  Winter
# 5689                     1.01           0.0            0.0  Winter
# 613                      0.00           0.0            0.0  Winter
# 1659                     0.00           0.0            0.0  Winter
# ...                       ...           ...            ...     ...
# 6820                     1.70           0.0            0.0  Autumn
# 4091                     0.00           0.0            0.0  Autumn
# 1627                     0.00           0.0            0.0  Autumn
# 54                       1.83           0.0            0.0  Autumn
# 121                      0.23           0.0            0.0  Autumn
#
#          Holiday Functioning Day
# 2198  No Holiday             Yes
# 2442  No Holiday             Yes
# 5689  No Holiday             Yes
# 613   No Holiday             Yes
# 1659  No Holiday             Yes
# ...          ...             ...
# 6820  No Holiday             Yes
# 4091  No Holiday             Yes
# 1627  No Holiday             Yes
# 54    No Holiday             Yes
# 121   No Holiday             Yes
#
# [7008 rows x 14 columns]

# %% [markdown]
# #### -> 계절 데이터에 결측치가 있으므로 3,4,5월은 봄, 6,7,8월은 여름, 9,10,11월은 가을, 12,1,2월은 겨울로 다시 설정.

# %%
def change(date):
    if date.month in [3, 4, 5]:
        return 'Spring'
    elif date.month in [6, 7, 8]:
        return 'Summer'
    elif date.month in [9, 10, 11]:
        return 'Autumn'
    elif date.month in [12, 1, 2]:
        return 'Winter'
    else:
        return 'N'
cycle['Seasons']=cycle['Date'].apply(lambda x : change(x))
cycle
# Out:
#            Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 2198 2017-12-01                181     6        13.030082           35
# 2442 2017-12-01                107     3        -6.200000           40
# 5689 2017-12-01                447    14         3.000000           26
# 613  2017-12-01                173     2        -6.000000           39
# 1659 2017-12-01                398    22        13.030082           83
# ...         ...                ...   ...              ...          ...
# 6820 2018-11-30                720    12         6.600000           35
# 4091 2018-11-30                116     4        13.030082           71
# 1627 2018-11-30                456     1         1.300000           63
# 54   2018-11-30                740    13         7.100000           24
# 121  2018-11-30               1047    17         6.000000           29
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 2198               1.3              2000                      -19.5
# 2442               0.9              2000                      -17.6
# 5689               2.0              2000                      -14.6
# 613                1.0              2000                      -17.7
# 1659               1.5              1380                       -3.4
# ...                ...               ...                        ...
# 6820               1.3              1409                       -7.8
# 4091               0.4              1345                       -5.1
# 1627               2.0              1379                       -4.9
# 54                 2.8              1838                      -12.1
# 121                2.1              1877                      -10.7
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 2198                     0.00           0.0            0.0  Winter
# 2442                     0.00           0.0            0.0  Winter
# 5689                     1.01           0.0            0.0  Winter
# 613                      0.00           0.0            0.0  Winter
# 1659                     0.00           0.0            0.0  Winter
# ...                       ...           ...            ...     ...
# 6820                     1.70           0.0            0.0  Autumn
# 4091                     0.00           0.0            0.0  Autumn
# 1627                     0.00           0.0            0.0  Autumn
# 54                       1.83           0.0            0.0  Autumn
# 121                      0.23           0.0            0.0  Autumn
#
#          Holiday Functioning Day
# 2198  No Holiday             Yes
# 2442  No Holiday             Yes
# 5689  No Holiday             Yes
# 613   No Holiday             Yes
# 1659  No Holiday             Yes
# ...          ...             ...
# 6820  No Holiday             Yes
# 4091  No Holiday             Yes
# 1627  No Holiday             Yes
# 54    No Holiday             Yes
# 121   No Holiday             Yes
#
# [7008 rows x 14 columns]

# %% [markdown]
# #### Wind speed (m/s) 피처의 결측값은 이 피처의 평균값으로 대체하겠다.

# %%
cycle['Wind speed (m/s)'].fillna(cycle['Wind speed (m/s)'].mean(),inplace=True)
cycle
# Out:
#            Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0    2017-12-01                181     6        13.030082           35
# 1    2017-12-01                107     3        -6.200000           40
# 2    2017-12-01                447    14         3.000000           26
# 3    2017-12-01                173     2        -6.000000           39
# 4    2017-12-01                398    22        13.030082           83
# ...         ...                ...   ...              ...          ...
# 7003 2018-11-30                720    12         6.600000           35
# 7004 2018-11-30                116     4        13.030082           71
# 7005 2018-11-30                456     1         1.300000           63
# 7006 2018-11-30                740    13         7.100000           24
# 7007 2018-11-30               1047    17         6.000000           29
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0                  1.3              2000                      -19.5
# 1                  0.9              2000                      -17.6
# 2                  2.0              2000                      -14.6
# 3                  1.0              2000                      -17.7
# 4                  1.5              1380                       -3.4
# ...                ...               ...                        ...
# 7003               1.3              1409                       -7.8
# 7004               0.4              1345                       -5.1
# 7005               2.0              1379                       -4.9
# 7006               2.8              1838                      -12.1
# 7007               2.1              1877                      -10.7
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 0                        0.00           0.0            0.0  Winter
# 1                        0.00           0.0            0.0  Winter
# 2                        1.01           0.0            0.0  Winter
# 3                        0.00           0.0            0.0  Winter
# 4                        0.00           0.0            0.0  Winter
# ...                       ...           ...            ...     ...
# 7003                     1.70           0.0            0.0  Autumn
# 7004                     0.00           0.0            0.0  Autumn
# 7005                     0.00           0.0            0.0  Autumn
# 7006                     1.83           0.0            0.0  Autumn
# 7007                     0.23           0.0            0.0  Autumn
#
#          Holiday Functioning Day  Month
# 0     No Holiday             Yes     12
# 1     No Holiday             Yes     12
# 2     No Holiday             Yes     12
# 3     No Holiday             Yes     12
# 4     No Holiday             Yes     12
# ...          ...             ...    ...
# 7003  No Holiday             Yes     11
# 7004  No Holiday             Yes     11
# 7005  No Holiday             Yes     11
# 7006  No Holiday             Yes     11
# 7007  No Holiday             Yes     11
#
# [7008 rows x 15 columns]

# %% [markdown]
# Index 깔끔하게 하게 위해서 0부터 7007까지로 수정

# %%
cycle.index=np.arange(7008)
cycle
# Out:
#            Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0    2017-12-01                181     6        13.030082           35
# 1    2017-12-01                107     3        -6.200000           40
# 2    2017-12-01                447    14         3.000000           26
# 3    2017-12-01                173     2        -6.000000           39
# 4    2017-12-01                398    22        13.030082           83
# ...         ...                ...   ...              ...          ...
# 7003 2018-11-30                720    12         6.600000           35
# 7004 2018-11-30                116     4        13.030082           71
# 7005 2018-11-30                456     1         1.300000           63
# 7006 2018-11-30                740    13         7.100000           24
# 7007 2018-11-30               1047    17         6.000000           29
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0                  1.3              2000                      -19.5
# 1                  0.9              2000                      -17.6
# 2                  2.0              2000                      -14.6
# 3                  1.0              2000                      -17.7
# 4                  1.5              1380                       -3.4
# ...                ...               ...                        ...
# 7003               1.3              1409                       -7.8
# 7004               0.4              1345                       -5.1
# 7005               2.0              1379                       -4.9
# 7006               2.8              1838                      -12.1
# 7007               2.1              1877                      -10.7
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 0                        0.00           0.0            0.0  Winter
# 1                        0.00           0.0            0.0  Winter
# 2                        1.01           0.0            0.0  Winter
# 3                        0.00           0.0            0.0  Winter
# 4                        0.00           0.0            0.0  Winter
# ...                       ...           ...            ...     ...
# 7003                     1.70           0.0            0.0  Autumn
# 7004                     0.00           0.0            0.0  Autumn
# 7005                     0.00           0.0            0.0  Autumn
# 7006                     1.83           0.0            0.0  Autumn
# 7007                     0.23           0.0            0.0  Autumn
#
#          Holiday Functioning Day  Month
# 0     No Holiday             Yes     12
# 1     No Holiday             Yes     12
# 2     No Holiday             Yes     12
# 3     No Holiday             Yes     12
# 4     No Holiday             Yes     12
# ...          ...             ...    ...
# 7003  No Holiday             Yes     11
# 7004  No Holiday             Yes     11
# 7005  No Holiday             Yes     11
# 7006  No Holiday             Yes     11
# 7007  No Holiday             Yes     11
#
# [7008 rows x 15 columns]

# %% [markdown]
# #### Season 피처 살펴보기

# %%
cycle['Seasons'].value_counts()
# Out:
# Summer    1771
# Autumn    1760
# Winter    1750
# Spring    1727
# Name: Seasons, dtype: int64

# %% [markdown]
# 추가로 월 별 데이터를 보기 위해 'Month' 열을 추가하자

# %%
cycle['Month']=cycle['Date'].dt.month
cycle.head(3)
# Out:
#         Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-12-01                181     6        13.030082           35
# 1 2017-12-01                107     3        -6.200000           40
# 2 2017-12-01                447    14         3.000000           26
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               1.3              2000                      -19.5
# 1               0.9              2000                      -17.6
# 2               2.0              2000                      -14.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                     0.00           0.0            0.0  Winter  No Holiday
# 1                     0.00           0.0            0.0  Winter  No Holiday
# 2                     1.01           0.0            0.0  Winter  No Holiday
#
#   Functioning Day  Month
# 0             Yes     12
# 1             Yes     12
# 2             Yes     12

# %%
cycle[['Date','Rented Bike Count','Hour','Temperature(°C)','Humidity(%)','Wind speed (m/s)','Visibility (10m)','Dew point temperature(°C)','Solar Radiation (MJ/m2)','Rainfall(mm)','Snowfall (cm)','Month']]
plt.figure(figsize=(10,7))  #사이즈 조정
sns.heatmap(cycle[['Date','Rented Bike Count','Hour','Temperature(°C)','Humidity(%)','Wind speed (m/s)','Visibility (10m)','Dew point temperature(°C)','Solar Radiation (MJ/m2)','Rainfall(mm)','Snowfall (cm)','Month']].corr(),annot=True)
plt.title('correlation heatmap') #상관계수 행렬 히트맵
# Out:
# Text(0.5, 1.0, 'correlation heatmap')

# %% [markdown]
# - 자전거 대여 수와의 상관계수가 가장 큰 피처는 'Temperature(°C)'이다.
# - 그 뒤로는 'Hour', 'Dew point temperature(°C)'가 뒤따른다.

# %% [markdown]
# 종속변수 Rented Bike Count를 살펴보자

# %%
cycle['Rented Bike Count'].value_counts()
# Out:
# 0       236
# 103      17
# 178      16
# 122      16
# 223      15
#        ...
# 2002      1
# 2014      1
# 2018      1
# 2656      1
# 2043      1
# Name: Rented Bike Count, Length: 2038, dtype: int64

# %% [markdown]
# Rented Bike Count와 다른 변수 간의 관계성 파악하기

# %% [markdown]
# 1. Temperature(°C)
# - 20~30 사이에 밀집 되어 있음.

# %%
sns.histplot(x='Temperature(°C)',y='Rented Bike Count',data=cycle,kde=True)
plt.title('Temperature(°C) histogram',fontsize=12)
plt.show()

# %%
sns.histplot(x='Temperature(°C)', y='Rented Bike Count',kde=True,data=cycle)
plt.title('Temperature(°C) & Rented Bike Count histogram',fontsize=12)
plt.show()

# %% [markdown]
# 2. Humidity(%)
# - 건조할 때보다 습할 때 자전거를 더 많이 탄다는 사실을 알 수 있음.

# %%
plt.scatter(cycle['Humidity(%)'],cycle['Rented Bike Count'])
plt.title('Humidity(%) & Rented Bike Count histogram',fontsize=12)
# Out:
# Text(0.5, 1.0, 'Humidity(%) & Rented Bike Count histogram')

# %% [markdown]
# 3. Wind speed (m/s)
# - 풍속 5m/s 이상부터는 자전거 이용 수가 줄어듦을 알 수 있음.

# %%
sns.histplot(x='Wind speed (m/s)',y='Rented Bike Count',data=cycle)
# Out:
# <AxesSubplot:xlabel='Wind speed (m/s)', ylabel='Rented Bike Count'>

# %% [markdown]
# 4. Dew point temperature(°C)
# - 노점온도가 높아짐에 따라 자전거 이용 수가 늘어남을 알 수 있음.

# %%
sns.histplot(x='Dew point temperature(°C)',y='Rented Bike Count',data=cycle)
# Out:
# <AxesSubplot:xlabel='Dew point temperature(°C)', ylabel='Rented Bike Count'>

# %% [markdown]
# 5. Solar Radiation (MJ/m2)

# %%
sns.histplot(x='Solar Radiation (MJ/m2)',y='Rented Bike Count',data=cycle)
# Out:
# <AxesSubplot:xlabel='Solar Radiation (MJ/m2)', ylabel='Rented Bike Count'>

# %% [markdown]
# 6. Rainfall(mm)
# - 강우량이 적은 쪽에 자전거 이용자 수가 많이 분포되어있음.

# %%
sns.histplot(x='Rainfall(mm)',y='Rented Bike Count',data=cycle)
# Out:
# <AxesSubplot:xlabel='Rainfall(mm)', ylabel='Rented Bike Count'>

# %% [markdown]
# 7. Snowfall (cm)
# - 적설량이 적은 쪽에 자전거 이용자 수가 많이 분포되어있음

# %%
sns.histplot(x='Snowfall (cm)',y='Rented Bike Count',data=cycle)
# Out:
# <AxesSubplot:xlabel='Snowfall (cm)', ylabel='Rented Bike Count'>

# %% [markdown]
# 8. Seasons
# - 겨울에 이용하는 자전거 수가 가장 적음.
# - 여름에 이용하는 자전거 수가 가장 많음.

# %%
sns.barplot(x='Seasons',y='Rented Bike Count',data=cycle)
plt.title('Rented Bike Count / Seasons')
# Out:
# Text(0.5, 1.0, 'Rented Bike Count / Seasons')

# %% [markdown]
# 9. Holiday
# - 휴일보다 평일에 이용하는 자전거 수가 더 많음.

# %%
sns.barplot(x='Holiday',y='Rented Bike Count',data=cycle)
# Out:
# <AxesSubplot:xlabel='Holiday', ylabel='Rented Bike Count'>

# %% [markdown]
# 10. Functioning Day
# - 기능 가능일에만 자전거를 이용할 수 있음.

# %%
sns.barplot(x='Functioning Day',y='Rented Bike Count',data=cycle)
# Out:
# <AxesSubplot:xlabel='Functioning Day', ylabel='Rented Bike Count'>

# %% [markdown]
# 11. Visibility
# - 시야가 잘 보일수록 자전거 이용 수가 많아짐.

# %%
plt.scatter(cycle["Visibility (10m)"], cycle["Rented Bike Count"], s=1)
plt.show()

# %% [markdown]
# 12. Month
# - 6월에 이용하는 자전거 수가 가장 많음.
# - 1,2,12월, 즉 겨울에 이용 수가 줄어드는 걸 확실히 알 수 있음.

# %%
sns.barplot(x=cycle['Month'],y=cycle['Rented Bike Count'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Rented Bike Count'>

# %% [markdown]
# # Hour와 Holiday 간 관계성 살펴보기
# - 휴일보다 휴일이 아닌 날에 더 오랜 시간 자전거를 이용한다는 사실을 알 수 있음.

# %%
sns.countplot(x='Hour',hue= 'Holiday',data=cycle)
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='count'>
